# %%
import pandas as pd

# %%
df = pd.read_csv("./dados.csv")

# %%
df.describe()
# Out:
#        maturidade  acabamento       item        peso        AOL  Width Rib  \
# count   33.000000   33.000000  33.000000   33.000000  33.000000  33.000000
# mean     2.636364    3.757576  21.454545  153.169697   2.243709   0.437915
# std      0.929320    0.435194  11.742261    8.769139   1.254910   0.293141
# min      2.000000    3.000000   1.000000  129.600000   0.000000   0.000000
# 25%      2.000000    4.000000  10.000000  148.800000   2.058057   0.000000
# 50%      2.000000    4.000000  23.000000  152.000000   2.598632   0.538678
# 75%      4.000000    4.000000  31.000000  156.600000   3.153393   0.662671
# max      4.000000    4.000000  40.000000  173.400000   3.702620   0.877453
#
#        Width Ext Fat      Score
# count      33.000000  33.000000
# mean        0.180178  63.967954
# std         0.305471   0.388629
# min         0.000000  62.844527
# 25%         0.000000  63.827073
# 50%         0.076584  63.966374
# 75%         0.230272  64.239919
# ...

# %%
df["Score"].hist()
# Out:
# <Axes: >
